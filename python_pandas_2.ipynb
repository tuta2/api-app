# %% [markdown]
# <a href="https://colab.research.google.com/github/tuta2/api-app/blob/main/python_pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **python pandas**

# %%
import pandas as pd

# %%
df2=pd.read_csv("Product.csv")

# %%
df2
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 0         101        Watch      Fashion    299       Delhi
# 1         102          Bag      Fashion   1350      Mumbai
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi
# 5         106          Oil      Grocery    110     Chennai
# 6         107       Laptop  Electronics  79999   Bengalore

# %%
#df.head() to show the top 5 indices/rows

df2.head()
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 0         101        Watch      Fashion    299       Delhi
# 1         102          Bag      Fashion   1350      Mumbai
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi

# %%
#df.head(2) to show the top 2 indices/rows

df2.head(2)
# Out:
#    Product_ID Product_Name Category  Price Seller_City
# 0         101        Watch  Fashion    299       Delhi
# 1         102          Bag  Fashion   1350      Mumbai

# %%
#df.tail() to show the bottom 5 indices/rows
df2.tail()
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi
# 5         106          Oil      Grocery    110     Chennai
# 6         107       Laptop  Electronics  79999   Bengalore
